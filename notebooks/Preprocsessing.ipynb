# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

# %%
# the intial read in
production_df = pd.read_excel("../data/Total production.xlsx")

production_df.head()
# Out:
#   Total production by all exporting countries Unnamed: 1  Unnamed: 2  \
# 0                       In thousand 60kg bags        NaN         NaN
# 1                                         NaN        NaN         NaN
# 2                                   Crop year        NaN     1990/91
# 3                                         NaN        NaN         NaN
# 4                                 April group        NaN  40795.2926
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2     1991/92     1992/93     1993/94     1994/95     1995/96     1996/97
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4  42529.5454  46868.2042  40166.7591  39990.3663  29395.9601  44297.8201
#
#    Unnamed: 9  ... Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# ...

# %%
# I needed to place the header at the 3rd row
production_df = pd.read_excel("../data/Total production.xlsx", header=3)
# change 2 column names
production_df = production_df.rename(columns={"Unnamed: 1" : "Coffee type", "Crop year" : "Country"})
# drop NaNs
production_df.dropna(how='all', inplace=True)

production_df.head(10)
# Out:
#                              Country Coffee type     1990/91     1991/92  \
# 1                        April group         NaN  40795.2926  42529.5454
# 2                             Angola       (R/A)     50.3450     79.3310
# 3   Bolivia (Plurinational State of)         (A)    122.7770    103.5360
# 4                             Brazil       (A/R)  27285.6286  27293.4934
# 5                            Burundi       (A/R)    487.3930    667.1990
# 6                            Ecuador       (A/R)   1503.8150   2123.8240
# 7                          Indonesia       (R/A)   7441.3830   8493.1960
# 8                         Madagascar         (R)    982.4470    932.5130
# 9                             Malawi         (A)    104.6280    124.2860
# 10                  Papua New Guinea       (A/R)    962.8410    746.8160
#
#        1992/93     1993/94     1994/95     1995/96     1996/97     1997/98  \
# 1   46868.2042  40166.7591  39990.3663  29395.9601  44297.8201  39475.8391
# ...

# %%
#Looking at the top row, I need to see what other rows do not have a coffee type
production_df['Coffee type'].isna()
# Out:
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 62     True
# 63     True
# Name: Coffee type, dtype: bool

# %%
# drop rows with NaN, then reset the index
production_df.drop(index=[1, 17, 26, 62, 63], axis=0, inplace=True)
production_df.reset_index(drop=True)
production_df.head()
# Out:
#                             Country Coffee type     1990/91     1991/92  \
# 2                            Angola       (R/A)     50.3450     79.3310
# 3  Bolivia (Plurinational State of)         (A)    122.7770    103.5360
# 4                            Brazil       (A/R)  27285.6286  27293.4934
# 5                           Burundi       (A/R)    487.3930    667.1990
# 6                           Ecuador       (A/R)   1503.8150   2123.8240
#
#       1992/93     1993/94    1994/95     1995/96    1996/97    1997/98  ...  \
# 2     77.5200     32.6080     76.802     62.1090     70.925     64.330  ...
# 3    120.2350     50.8230    116.944    142.4850    124.579    140.719  ...
# 4  34603.3542  28166.9786  28192.047  18060.2022  29196.743  26148.004  ...
# 5    620.2380    393.3540    664.143    433.9800    400.969    249.785  ...
# 6   1185.4800   2069.0070   2375.766   1888.2330   1992.914   1190.663  ...
#
# ...

# %%
# replace the coffee types with something more readable
production_df.replace({"(A)" : "Arabica",
                       "(R)" : "Robusta",
                       "(R/A)" : "Robusta/Arabica",
                       "(A/R)" : "Arabica/Robusta"},
                      inplace=True)
print(production_df.shape)
production_df.head()
# Out:
# (55, 32)
#                             Country      Coffee type     1990/91     1991/92  \
# 2                            Angola  Robusta/Arabica     50.3450     79.3310
# 3  Bolivia (Plurinational State of)          Arabica    122.7770    103.5360
# 4                            Brazil  Arabica/Robusta  27285.6286  27293.4934
# 5                           Burundi  Arabica/Robusta    487.3930    667.1990
# 6                           Ecuador  Arabica/Robusta   1503.8150   2123.8240
#
#       1992/93     1993/94    1994/95     1995/96    1996/97    1997/98  ...  \
# 2     77.5200     32.6080     76.802     62.1090     70.925     64.330  ...
# 3    120.2350     50.8230    116.944    142.4850    124.579    140.719  ...
# 4  34603.3542  28166.9786  28192.047  18060.2022  29196.743  26148.004  ...
# 5    620.2380    393.3540    664.143    433.9800    400.969    249.785  ...
# 6   1185.4800   2069.0070   2375.766   1888.2330   1992.914   1190.663  ...
#
# ...

# %%
production_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 2 to 60
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      55 non-null     object
#  1   Coffee type  55 non-null     object
#  2   1990/91      55 non-null     float64
#  3   1991/92      55 non-null     float64
#  4   1992/93      55 non-null     float64
#  5   1993/94      55 non-null     float64
#  6   1994/95      55 non-null     float64
#  7   1995/96      55 non-null     float64
#  8   1996/97      55 non-null     float64
#  9   1997/98      55 non-null     float64
#  10  1998/99      55 non-null     float64
#  11  1999/00      55 non-null     float64
#  12  2000/01      55 non-null     float64
#  13  2001/02      55 non-null     float64
#  14  2002/03      55 non-null     float64
#  15  2003/04      55 non-null     float64
#  16  2004/05      55 non-null     float64
#  17  2005/06      55 non-null     float64
# ...

# %%
production_df.iloc[:, 2:32].round(2)
# Out:
#      1990/91   1991/92   1992/93   1993/94   1994/95   1995/96   1996/97  \
# 2      50.34     79.33     77.52     32.61     76.80     62.11     70.92
# 3     122.78    103.54    120.24     50.82    116.94    142.49    124.58
# 4   27285.63  27293.49  34603.35  28166.98  28192.05  18060.20  29196.74
# 5     487.39    667.20    620.24    393.35    664.14    433.98    400.97
# 6    1503.82   2123.82   1185.48   2069.01   2375.77   1888.23   1992.91
# 7    7441.38   8493.20   5569.48   6743.29   5367.88   4573.43   8220.58
# 8     982.45    932.51   1121.68    441.86    641.37    785.01    849.01
# 9     104.63    124.29    137.16     62.11     84.11     91.24     48.65
# 10    962.84    746.82    900.11   1019.48   1138.66   1002.36   1089.35
# 11    130.63     79.65     54.29     66.53     25.26     26.25     30.84
# 12    936.63   1200.47   1761.95    665.50   1178.63   1870.94   1805.86
# 13    534.88    483.83    638.88    443.62     22.45    329.08    293.00
# ...

# %%
for col in [x for x in production_df.columns if x != 'Country' and x for x in production_df.columns if x != 'Coffee Type']:
    production_df[col] = production_df[col].astype(float).round(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 for col in [x for x in production_df.columns if x != 'Country' and x for x in production_df.columns if x != 'Coffee Type']:
# ----> 2     production_df[col] = production_df[col].astype(float).round(2)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
production_df.sample(5)
# Out:
#      Country      Coffee type   1990/91   1991/92   1992/93    1993/94  \
# 47    Mexico  Arabica/Robusta  4674.245  4727.206  3400.811  5023.4880
# 35  Ethiopia          Arabica  2909.451  2924.664  1825.171  2967.0040
# 19      Cuba          Arabica   414.212   302.097   284.237   285.4040
# 24    Zambia          Arabica    22.686    29.138    29.307    26.6060
# 11  Paraguay                0   130.627    79.653    54.291    66.5275
#
#       1994/95    1995/96    1996/97    1997/98  ...    2010/11    2011/12  \
# 47  4158.7770  5299.8880  5109.5510  4801.5610  ...  4001.4319  4561.0578
# 35  2762.7300  3165.3220  3407.4420  3056.8640  ...  5560.3848  5650.4099
# 19   284.3150   284.9550   365.8650   300.0210  ...   108.4970   100.1580
# 24    21.4550    26.3330    33.0250    38.4620  ...    13.1783    11.1889
# 11    25.2643    26.2539    30.8431    49.3411  ...    20.1967    20.0195
#
#       2012/13    2013/14    2014/15    2015/16    2016/17    2017/18  \
# ...
